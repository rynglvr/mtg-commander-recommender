# %%
# Install packages we need
# !pip install requests pandas
# Out:
# Requirement already satisfied: requests in ./mtg-env-311/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: pandas in ./mtg-env-311/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./mtg-env-311/lib/python3.11/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./mtg-env-311/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./mtg-env-311/lib/python3.11/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./mtg-env-311/lib/python3.11/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in ./mtg-env-311/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./mtg-env-311/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./mtg-env-311/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./mtg-env-311/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./mtg-env-311/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import json

# Test connection to Scryfall API
response = requests.get("https://api.scryfall.com/cards/search?q=is:commander")
print(f"Status Code: {response.status_code}")
print(f"Found {response.json()['total_cards']} commanders")
# Out:
# Status Code: 200
# Found 2703 commanders

# %%
# Get a specific commander to understand the data structure
response = requests.get("https://api.scryfall.com/cards/named?exact=Atraxa, Praetors' Voice")
card_data = response.json()

# Pretty print the structure
print(json.dumps(card_data, indent=2)[:2000])  # First 2000 characters
print("...")
print(f"Total keys in card data: {len(card_data.keys())}")
print(f"Available keys: {list(card_data.keys())}")
# Out:
# {
#   "object": "card",
#   "id": "d0d33d52-3d28-4635-b985-51e126289259",
#   "oracle_id": "7e6b9b59-cd68-4e3c-827b-38833c92d6eb",
#   "multiverse_ids": [
#     489863
#   ],
#   "mtgo_id": 82414,
#   "tcgplayer_id": 214833,
#   "cardmarket_id": 462559,
#   "name": "Atraxa, Praetors' Voice",
#   "lang": "en",
#   "released_at": "2020-08-07",
#   "uri": "https://api.scryfall.com/cards/d0d33d52-3d28-4635-b985-51e126289259",
#   "scryfall_uri": "https://scryfall.com/card/2xm/190/atraxa-praetors-voice?utm_source=api",
#   "layout": "normal",
#   "highres_image": true,
#   "image_status": "highres_scan",
#   "image_uris": {
#     "small": "https://cards.scryfall.io/small/front/d/0/d0d33d52-3d28-4635-b985-51e126289259.jpg?1599707796",
#     "normal": "https://cards.scryfall.io/normal/front/d/0/d0d33d52-3d28-4635-b985-51e126289259.jpg?1599707796",
#     "large": "https://cards.scryfall.io/large/front/d/0/d0d33d52-3d28-4635-b985-51e126289259.jpg?1599707796",
#     "png": "https://cards.scryfall.io/png/front/d/0/d0d33d52-3d28-4635-b985-51e126289259.png?1599707796",
#     "art_crop": "https://cards.scryfall.io/art_crop/front/d/0/d0d33d52-3d28-4635-b985-51e126289259.jpg?1599707796",
#     "border_crop": "https://cards.scryfall.io/border_crop/front/d/0/d0d33d52-3d28-4635-b985-51e126289259.jpg?1599707796"
#   },
#   "mana_cost": "{G}{W}{U}{B}",
#   "cmc": 4.0,
#   "type_line": "Legendary Creature \u2014 Phyrexian Angel Horror",
#   "oracle_text": "Flying, vigilance, deathtouch, lifelink\nAt the beginning of your end step, proliferate. (Choose any number of permanents and/or players, then give each another counter of each kind already there.)",
#   "power": "4",
#   "toughness": "4",
#   "colors": [
#     "B",
#     "G",
#     "U",
#     "W"
#   ],
#   "color_identity": [
#     "B",
#     "G",
#     "U",
#     "W"
#   ],
#   "keywords": [
#     "Deathtouch",
#     "Flying",
#     "Lifelink",
#     "Vigilance",
#     "Proliferate"
#   ],
#   "legalities": {
#     "standard": "not_legal",
#     "future": "not_legal",
#     "historic": "legal",
#     "timeless": "legal",
#     "gladiator": "l
# ...
# Total keys in card data: 65
# Available keys: ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'power', 'toughness', 'colors', 'color_identity', 'keywords', 'legalities', 'games', 'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame', 'frame_effects', 'security_stamp', 'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank', 'preview', 'prices', 'related_uris', 'purchase_uris']

# %%
# Extract the fields we'll need for our recommender
important_fields = {
    'name': card_data.get('name'),
    'mana_cost': card_data.get('mana_cost'),
    'type_line': card_data.get('type_line'),
    'oracle_text': card_data.get('oracle_text'),
    'colors': card_data.get('colors'),
    'keywords': card_data.get('keywords'),
    'power': card_data.get('power'),
    'toughness': card_data.get('toughness'),
    'cmc': card_data.get('cmc')  # converted mana cost
}

for key, value in important_fields.items():
    print(f"{key}: {value}")
# Out:
# name: Atraxa, Praetors' Voice
# mana_cost: {G}{W}{U}{B}
# type_line: Legendary Creature — Phyrexian Angel Horror
# oracle_text: Flying, vigilance, deathtouch, lifelink
# At the beginning of your end step, proliferate. (Choose any number of permanents and/or players, then give each another counter of each kind already there.)
# colors: ['B', 'G', 'U', 'W']
# keywords: ['Deathtouch', 'Flying', 'Lifelink', 'Vigilance', 'Proliferate']
# power: 4
# toughness: 4
# cmc: 4.0

# %%
import pandas as pd
import time

def get_affordable_cards():
    all_cards = []
    page = 1
    
    while True:
        # Search for cards under $5 that are legal in Commander
        url = f"https://api.scryfall.com/cards/search?q=legal:commander+usd<5&page={page}"
        response = requests.get(url)
        
        if response.status_code != 200:
            break
            
        data = response.json()
        all_cards.extend(data['data'])
        
        print(f"Page {page}: Got {len(data['data'])} cards. Total so far: {len(all_cards)}")
        
        if not data.get('has_more'):
            break
            
        page += 1
        time.sleep(0.03)  # Be nice to the API
        
        # Limit for testing - remove this later
        # if page > 25:  # Just get first 3 pages for now
        #    break
    
    return all_cards

# This might take a minute or two
cards_data = get_affordable_cards()
print(f"Total cards collected: {len(cards_data)}")
# Out:
# Page 1: Got 175 cards. Total so far: 175
# Page 2: Got 175 cards. Total so far: 350
# Page 3: Got 175 cards. Total so far: 525
# Page 4: Got 175 cards. Total so far: 700
# Page 5: Got 175 cards. Total so far: 875
# Page 6: Got 175 cards. Total so far: 1050
# Page 7: Got 175 cards. Total so far: 1225
# Page 8: Got 175 cards. Total so far: 1400
# Page 9: Got 175 cards. Total so far: 1575
# Page 10: Got 175 cards. Total so far: 1750
# Page 11: Got 175 cards. Total so far: 1925
# Page 76: Got 175 cards. Total so far: 13300
# Page 77: Got 175 cards. Total so far: 13475
# Page 78: Got 175 cards. Total so far: 13650
# Page 79: Got 175 cards. Total so far: 13825
# Page 80: Got 175 cards. Total so far: 14000
# Page 81: Got 175 cards. Total so far: 14175
# Page 82: Got 175 cards. Total so far: 14350
# Page 83: Got 175 cards. Total so far: 14525
# Page 84: Got 175 cards. Total so far: 14700
# Page 85: Got 175 cards. Total so far: 14875
# Page 86: Got 175 cards. Total so far: 15050
# Page 87: Got 175 cards. Total so far: 15225
# Page 88: Got 175 cards. Total so far: 15400
# Page 89: Got 175 cards. Total so far: 15575
# Page 90: Got 175 cards. Total so far: 15750
# Page 91: Got 175 cards. Total so far: 15925
# Page 92: Got 175 cards. Total so far: 16100
# Page 93: Got 175 cards. Total so far: 16275
# Total cards collected: 16275

# %%
# Create DataFrame with the fields we need
df = pd.DataFrame(cards_data)

print(f"DataFrame shape: {df.shape}")
print(f"Columns available: {df.columns.tolist()}")

# Look at the first few cards
print("\nFirst 3 card names:")
print(df[['name', 'type_line', 'oracle_text']].head(3))
# Out:
# DataFrame shape: (16275, 80)
# Columns available: ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors', 'color_identity', 'keywords', 'legalities', 'games', 'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id', 'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame', 'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank', 'preview', 'prices', 'related_uris', 'purchase_uris', 'power', 'toughness', 'all_parts', 'frame_effects', 'security_stamp', 'penny_rank', 'promo_types', 'produced_mana', 'mtgo_foil_id', 'card_faces', 'watermark', 'loyalty', 'color_indicator', 'tcgplayer_etched_id', 'attraction_lights', 'flavor_name', 'printed_name']
#
# First 3 card names:
#                       name                          type_line  \
# 0                  +2 Mace               Artifact — Equipment
# 1          Aarakocra Sneak              Creature — Bird Rogue
# 2  Aatchik, Emerald Radian  Legendary Creature — Insect Druid
#
#                                          oracle_text
# 0  Equipped creature gets +2/+2.\nEquip {3} ({3}:...
# 1  Flying\nWhen this creature enters, you take th...
# 2  When Aatchik enters, create a 1/1 green Insect...

# %%
# Remove cards without oracle text (lands, some artifacts)
df_clean = df[df['oracle_text'].notna()].copy()

# Add a simplified text column for ML processing
df_clean['combined_text'] = (
    df_clean['oracle_text'].fillna('') + ' ' + 
    df_clean['type_line'].fillna('') + ' ' +
    df_clean['keywords'].astype(str)
)

print(f"Cards with oracle text: {len(df_clean)}")
print(f"Sample combined text:")
print(df_clean['combined_text'].iloc[0][:200] + "...")
# Out:
# Cards with oracle text: 15839
# Sample combined text:
# Equipped creature gets +2/+2.
# Equip {3} ({3}: Attach to target creature you control. Equip only as a sorcery.) Artifact — Equipment ['Equip']...

# %%
# Install our ML libraries
# !pip install tensorflow scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: tensorflow in ./mtg-env-311/lib/python3.11/site-packages (2.16.2)
# Requirement already satisfied: scikit-learn in ./mtg-env-311/lib/python3.11/site-packages (1.7.0)
# Requirement already satisfied: matplotlib in ./mtg-env-311/lib/python3.11/site-packages (3.10.3)
# Requirement already satisfied: seaborn in ./mtg-env-311/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (1.72.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in ./mtg-env-311/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.1.3)
# Requirement already satisfied: scipy>=1.8.0 in ./mtg-env-311/lib/python3.11/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in ./mtg-env-311/lib/python3.11/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./mtg-env-311/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in ./mtg-env-311/lib/python3.11/site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./mtg-env-311/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in ./mtg-env-311/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in ./mtg-env-311/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in ./mtg-env-311/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in ./mtg-env-311/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./mtg-env-311/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./mtg-env-311/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./mtg-env-311/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./mtg-env-311/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in ./mtg-env-311/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)

# %%
# Install TensorFlow for Apple Silicon
# !pip install tensorflow-macos tensorflow-metal scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: tensorflow-macos in ./mtg-env-311/lib/python3.11/site-packages (2.16.2)
# Requirement already satisfied: tensorflow-metal in ./mtg-env-311/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: scikit-learn in ./mtg-env-311/lib/python3.11/site-packages (1.7.0)
# Requirement already satisfied: matplotlib in ./mtg-env-311/lib/python3.11/site-packages (3.10.3)
# Requirement already satisfied: seaborn in ./mtg-env-311/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: tensorflow==2.16.2 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow-macos) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: packaging in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.3)
# Requirement already satisfied: setuptools in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.72.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./mtg-env-311/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in ./mtg-env-311/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./mtg-env-311/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./mtg-env-311/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.1.3)
# Requirement already satisfied: wheel~=0.35 in ./mtg-env-311/lib/python3.11/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: scipy>=1.8.0 in ./mtg-env-311/lib/python3.11/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in ./mtg-env-311/lib/python3.11/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./mtg-env-311/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./mtg-env-311/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in ./mtg-env-311/lib/python3.11/site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: rich in ./mtg-env-311/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (14.0.0)
# Requirement already satisfied: namex in ./mtg-env-311/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.0)
# Requirement already satisfied: optree in ./mtg-env-311/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in ./mtg-env-311/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./mtg-env-311/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./mtg-env-311/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./mtg-env-311/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./mtg-env-311/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in ./mtg-env-311/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.2)

# %%
# Test TensorFlow installation
import tensorflow as tf
import sklearn
import pandas as pd
import numpy as np

print(f"TensorFlow version: {tf.__version__}")
print(f"Scikit-learn version: {sklearn.__version__}")
print(f"GPU available: {tf.config.list_physical_devices('GPU')}")
print("All libraries imported successfully!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# TensorFlow version: 2.16.2
# Scikit-learn version: 1.7.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# All libraries imported successfully!

# %%
import requests
import pandas as pd
import time

# Rerun the data collection (this should be familiar now)
def get_affordable_cards(max_pages=2500):
    all_cards = []
    page = 1
    
    while True:
        url = f"https://api.scryfall.com/cards/search?q=legal:commander+usd<10&page={page}"
        response = requests.get(url)
        
        if response.status_code != 200:
            print(f"Error on page {page}: {response.status_code}")
            break
            
        data = response.json()
        all_cards.extend(data['data'])
        
        print(f"Page {page}: Got {len(data['data'])} cards. Total so far: {len(all_cards)}")
# Page 125: Got 175 cards. Total so far: 21875
# Page 126: Got 175 cards. Total so far: 22050
# Page 127: Got 175 cards. Total so far: 22225
# Page 128: Got 175 cards. Total so far: 22400
# Page 129: Got 175 cards. Total so far: 22575
# Page 130: Got 175 cards. Total so far: 22750
# Page 131: Got 175 cards. Total so far: 22925
# Page 132: Got 175 cards. Total so far: 23100
# Page 133: Got 175 cards. Total so far: 23275
# Page 134: Got 175 cards. Total so far: 23450
# Page 135: Got 175 cards. Total so far: 23625
# Page 136: Got 175 cards. Total so far: 23800
# Page 137: Got 175 cards. Total so far: 23975
# Page 138: Got 175 cards. Total so far: 24150
# Page 139: Got 175 cards. Total so far: 24325
# Page 140: Got 175 cards. Total so far: 24500
# Page 141: Got 175 cards. Total so far: 24675
# Page 142: Got 175 cards. Total so far: 24850
# Page 143: Got 175 cards. Total so far: 25025
# Page 144: Got 175 cards. Total so far: 25200
# Page 145: Got 175 cards. Total so far: 25375
# Page 146: Got 175 cards. Total so far: 25550
# Page 147: Got 175 cards. Total so far: 25725
# Page 148: Got 175 cards. Total so far: 25900
# Page 149: Got 175 cards. Total so far: 26075
# Page 150: Got 175 cards. Total so far: 26250
# Page 151: Got 175 cards. Total so far: 26425
# Page 152: Got 175 cards. Total so far: 26600
# Page 153: Got 175 cards. Total so far: 26775
# Page 154: Got 175 cards. Total so far: 26950
# Page 155: Got 175 cards. Total so far: 27125
# Page 156: Got 175 cards. Total so far: 27300
# Page 157: Got 175 cards. Total so far: 27475
# Page 158: Got 175 cards. Total so far: 27650
# Page 159: Got 175 cards. Total so far: 27825
# Page 160: Got 175 cards. Total so far: 28000
# Page 161: Got 175 cards. Total so far: 28175
# Page 162: Got 167 cards. Total so far: 28342
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 37
#      35 # Save to file so we don't lose it again!
#      36 df = pd.DataFrame(cards_data)
# ---> 37 df.to_csv('../data/mtg_cards_raw.csv', index=False)
#      38 print(f"Saved {len(cards_data)} cards to file!")
#
# File ~/mtg-commander-recommender/mtg-env-311/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/mtg-commander-recommender/mtg-env-311/lib/python3.11/site-packages/pandas/core/generic.py:3986, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3975 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3977 formatter = DataFrameFormatter(
#    3978     frame=df,
#    3979     header=header,
#    (...)   3983     decimal=decimal,
#    3984 )
# -> 3986 return DataFrameRenderer(formatter).to_csv(
#    3987     path_or_buf,
#    3988     lineterminator=lineterminator,
#    3989     sep=sep,
#    3990     encoding=encoding,
#    3991     errors=errors,
#    3992     compression=compression,
#    3993     quoting=quoting,
#    3994     columns=columns,
#    3995     index_label=index_label,
#    3996     mode=mode,
#    3997     chunksize=chunksize,
#    3998     quotechar=quotechar,
#    3999     date_format=date_format,
#    4000     doublequote=doublequote,
#    4001     escapechar=escapechar,
#    4002     storage_options=storage_options,
#    4003 )
#
# File ~/mtg-commander-recommender/mtg-env-311/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/mtg-commander-recommender/mtg-env-311/lib/python3.11/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/mtg-commander-recommender/mtg-env-311/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/mtg-commander-recommender/mtg-env-311/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../data'

# %%
# Save to file so we don't lose it again!
import os

# Create the data directory if it doesn't exist
os.makedirs('data', exist_ok=True)

df = pd.DataFrame(cards_data)
df.to_csv('data/mtg_cards_raw.csv', index=False)
print(f"Saved {len(cards_data)} cards to data/mtg_cards_raw.csv!")
# Out:
# (28342, 82)

# %%
# Also save just the fields we need for ML
df_clean = df[df['oracle_text'].notna()].copy()
df_clean['combined_text'] = (
    df_clean['oracle_text'].fillna('') + ' ' + 
    df_clean['type_line'].fillna('') + ' ' +
    df_clean['keywords'].astype(str)
)

df_clean.to_csv('data/mtg_cards_clean.csv', index=False)
print(f"Saved {len(df_clean)} cleaned cards!")
# Out:
# Saved 27623 cleaned cards!
